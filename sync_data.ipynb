# %%
ip_address = "69.30.85.101"
port_number = "22117"
username = "root"
identity_file = "/Users/ishiz/.ssh/id_ed25519"
local_path = "/Users/ishiz/pyworks/competitions/atma_22_ca/data/raw/input/images"
remote_path = "/workspace/atma_22_ca/data/raw/input/"

# %%
# !scp -r -P {port_number} -i {identity_file} {local_path} {username}@{ip_address}:{remote_path}

# %%
# !rsync -avz --progress -e "ssh -p 22117" ./data/raw/ root@69.30.85.101:/workspace/atma_22_ca/data/raw/
